# %% [markdown]
# # Prompting with LangChain in Jupyter
#
# This notebook demonstrates how to use LangChain for basic prompting with OpenAI models.

# %%
# Install LangChain and OpenAI
# !pip install langchain openai
# Out:
# Requirement already satisfied: langchain in e:\mca\sem3\genai\lab\.venv\lib\site-packages (0.3.27)
# Requirement already satisfied: openai in e:\mca\sem3\genai\lab\.venv\lib\site-packages (0.28.0)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.72 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from langchain) (0.3.76)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from langchain) (0.3.11)
# Requirement already satisfied: langsmith>=0.1.17 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from langchain) (0.4.31)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from langchain) (2.11.9)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from langchain) (2.0.43)
# Requirement already satisfied: requests<3,>=2 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from langchain) (2.32.5)
# Requirement already satisfied: PyYAML>=5.3 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from langchain) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (1.33)
# Requirement already satisfied: typing-extensions>=4.7 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (4.15.0)
# Requirement already satisfied: packaging>=23.2 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (25.0)
# Requirement already satisfied: jsonpointer>=1.9 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.72->langchain) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from requests<3,>=2->langchain) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from requests<3,>=2->langchain) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from requests<3,>=2->langchain) (2025.8.3)
# Requirement already satisfied: greenlet>=1 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.2.4)
# Requirement already satisfied: tqdm in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from openai) (4.67.1)
# Requirement already satisfied: aiohttp in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from openai) (3.12.15)
# Requirement already satisfied: httpx<1,>=0.23.0 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from langsmith>=0.1.17->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from langsmith>=0.1.17->langchain) (3.11.3)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from langsmith>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from langsmith>=0.1.17->langchain) (0.25.0)
# Requirement already satisfied: anyio in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (4.10.0)
# Requirement already satisfied: httpcore==1.* in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (1.0.9)
# Requirement already satisfied: h11>=0.16 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (0.16.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from aiohttp->openai) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from aiohttp->openai) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from aiohttp->openai) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from aiohttp->openai) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from aiohttp->openai) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from aiohttp->openai) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from aiohttp->openai) (1.20.1)
# Requirement already satisfied: sniffio>=1.1 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (1.3.1)
# Requirement already satisfied: colorama in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from tqdm->openai) (0.4.6)

# %%
pip install langchain_community
# Out:
# Requirement already satisfied: langchain_community in e:\mca\sem3\genai\lab\.venv\lib\site-packages (0.3.30)
# Requirement already satisfied: langchain-core<2.0.0,>=0.3.75 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from langchain_community) (0.3.76)
# Requirement already satisfied: langchain<2.0.0,>=0.3.27 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from langchain_community) (0.3.27)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from langchain_community) (2.0.43)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from langchain_community) (2.32.5)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from langchain_community) (6.0.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from langchain_community) (3.12.15)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from langchain_community) (9.1.2)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from langchain_community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from langchain_community) (2.11.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from langchain_community) (0.4.31)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from langchain_community) (0.4.1)
# Requirement already satisfied: numpy>=2.1.0 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from langchain_community) (2.3.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.20.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain_community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain_community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from langchain<2.0.0,>=0.3.27->langchain_community) (0.3.11)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from langchain<2.0.0,>=0.3.27->langchain_community) (2.11.9)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from langchain-core<2.0.0,>=0.3.75->langchain_community) (1.33)
# Requirement already satisfied: typing-extensions>=4.7 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from langchain-core<2.0.0,>=0.3.75->langchain_community) (4.15.0)
# Requirement already satisfied: packaging>=23.2 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from langchain-core<2.0.0,>=0.3.75->langchain_community) (25.0)
# Requirement already satisfied: jsonpointer>=1.9 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<2.0.0,>=0.3.75->langchain_community) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (3.11.3)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (0.25.0)
# Requirement already satisfied: anyio in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (4.10.0)
# Requirement already satisfied: certifi in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (1.0.9)
# Requirement already satisfied: idna in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (3.10)
# Requirement already satisfied: h11>=0.16 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<2.0.0,>=0.3.27->langchain_community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<2.0.0,>=0.3.27->langchain_community) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<2.0.0,>=0.3.27->langchain_community) (0.4.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain_community) (1.1.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain_community) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain_community) (2.5.0)
# Requirement already satisfied: greenlet>=1 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain_community) (3.2.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain_community) (1.1.0)
# Requirement already satisfied: sniffio>=1.1 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (1.3.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install openai==0.28
# Out:
# Requirement already satisfied: openai==0.28 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (0.28.0)
# Requirement already satisfied: requests>=2.20 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from openai==0.28) (2.32.5)
# Requirement already satisfied: tqdm in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from openai==0.28) (4.67.1)
# Requirement already satisfied: aiohttp in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from openai==0.28) (3.12.15)
# Requirement already satisfied: charset_normalizer<4,>=2 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from requests>=2.20->openai==0.28) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from requests>=2.20->openai==0.28) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from requests>=2.20->openai==0.28) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from requests>=2.20->openai==0.28) (2025.8.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from aiohttp->openai==0.28) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from aiohttp->openai==0.28) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from aiohttp->openai==0.28) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from aiohttp->openai==0.28) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from aiohttp->openai==0.28) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from aiohttp->openai==0.28) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from aiohttp->openai==0.28) (1.20.1)
# Requirement already satisfied: colorama in e:\mca\sem3\genai\lab\.venv\lib\site-packages (from tqdm->openai==0.28) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Basic Prompting with LangChain
#
# LangChain provides a simple interface to interact with LLMs using prompts.

# %% [markdown]
# ## Instruction-based Prompting

# %% [markdown]
# ## Chain-of-Thought (CoT) Prompting

# %%
cot_prompt = (
    "If a train leaves the station at 3 PM and travels at 60 km/h, "
    "how far will it have traveled by 6 PM? Please show your reasoning step by step."
)
response_cot = llm(cot_prompt)
print("Chain-of-Thought Response:", response_cot)

# %% [markdown]
# ## Prompting with Hugging Face (LangChain)

# %%
from langchain.llms import HuggingFaceHub
import os

os.environ["HUGGINGFACEHUB_API_TOKEN"] = (
    "your-huggingface-api-token"  # Replace with your token
)

hf_llm = HuggingFaceHub(
    repo_id="gpt2", model_kwargs={"temperature": 0.7, "max_length": 50}
)
prompt_hf = "Tell a joke about computers."
response_hf = hf_llm(prompt_hf)
print("Hugging Face Response:", response_hf)

# %% [markdown]
# ## Prompting with Gemini (Google Generative AI)

# %%
# Gemini API example (Google Generative AI)
# Requires: pip install google-generativeai
import google.generativeai as genai

genai.configure(api_key="your-gemini-api-key")  # Replace with your Gemini API key
gemini_model = genai.GenerativeModel("gemini-pro")
prompt_gemini = "Summarize the importance of water in one sentence."
response_gemini = gemini_model.generate_content(prompt_gemini)
print("Gemini Response:", response_gemini.text)

# %% [markdown]
# ## Prompting with OpenRouter (LangChain)

# %%
from langchain.llms import OpenAI

os.environ["OPENAI_API_KEY"] = (
    "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"  # Replace with your OpenRouter key
)
# OpenRouter with LangChain: Use the correct model name and pass 'prompt' as a keyword argument
openrouter_llm = OpenAI(
    model_name="openrouter/openai/gpt-3.5-turbo",
    temperature=0.7,
    openai_api_base="https://openrouter.ai/api/v1",
)
prompt_openrouter = "Explain photosynthesis in simple terms."
response_openrouter = openrouter_llm(prompt=prompt_openrouter)
print("OpenRouter Response:", response_openrouter)
# Out:
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# Cell In[12], line 13
#       7 openrouter_llm = OpenAI(
#       8     model_name="openrouter/openai/gpt-3.5-turbo",
#       9     temperature=0.7,
#      10     openai_api_base="https://openrouter.ai/api/v1",
#      11 )
#      12 prompt_openrouter = "Explain photosynthesis in simple terms."
# ---> 13 response_openrouter = openrouter_llm(prompt=prompt_openrouter)
#      14 print("OpenRouter Response:", response_openrouter)
#
# File e:\MCA\Sem3\GenAI\Lab\.venv\Lib\site-packages\langchain_core\_api\deprecation.py:193, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     191     warned = True
#     192     emit_warning()
# --> 193 return wrapped(*args, **kwargs)
#
# File e:\MCA\Sem3\GenAI\Lab\.venv\Lib\site-packages\langchain_core\language_models\llms.py:1347, in BaseLLM.__call__(self, prompt, stop, callbacks, tags, metadata, **kwargs)
#    1340     msg = (
#    1341         "Argument `prompt` is expected to be a string. Instead found "
#    1342         f"{type(prompt)}. If you want to run the LLM on multiple prompts, use "
#    1343         "`generate` instead."
#    1344     )
#    1345     raise ValueError(msg)  # noqa: TRY004
#    1346 return (
# -> 1347     self.generate(
#    1348         [prompt],
#    1349         stop=stop,
#    1350         callbacks=callbacks,
#    1351         tags=tags,
#    1352         metadata=metadata,
#    1353         **kwargs,
#    1354     )
#    1355     .generations[0][0]
#    1356     .text
#    1357 )
#
# File e:\MCA\Sem3\GenAI\Lab\.venv\Lib\site-packages\langchain_core\language_models\llms.py:1000, in BaseLLM.generate(self, prompts, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     985 if (self.cache is None and get_llm_cache() is None) or self.cache is False:
#     986     run_managers = [
#     987         callback_manager.on_llm_start(
#     988             self._serialized,
#    (...)    998         )
#     999     ]
# -> 1000     return self._generate_helper(
#    1001         prompts,
#    1002         stop,
#    1003         run_managers,
#    1004         new_arg_supported=bool(new_arg_supported),
#    1005         **kwargs,
#    1006     )
#    1007 if len(missing_prompts) > 0:
#    1008     run_managers = [
#    1009         callback_managers[idx].on_llm_start(
#    1010             self._serialized,
#    (...)   1017         for idx in missing_prompt_idxs
#    1018     ]
#
# File e:\MCA\Sem3\GenAI\Lab\.venv\Lib\site-packages\langchain_core\language_models\llms.py:815, in BaseLLM._generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     804 def _generate_helper(
#     805     self,
#     806     prompts: list[str],
#    (...)    811     **kwargs: Any,
#     812 ) -> LLMResult:
#     813     try:
#     814         output = (
# --> 815             self._generate(
#     816                 prompts,
#     817                 stop=stop,
#     818                 # TODO: support multiple run managers
#     819                 run_manager=run_managers[0] if run_managers else None,
#     820                 **kwargs,
#     821             )
#     822             if new_arg_supported
#     823             else self._generate(prompts, stop=stop)
#     824         )
#     825     except BaseException as e:
#     826         for run_manager in run_managers:
#
# File e:\MCA\Sem3\GenAI\Lab\.venv\Lib\site-packages\langchain_community\llms\openai.py:463, in BaseOpenAI._generate(self, prompts, stop, run_manager, **kwargs)
#     451     choices.append(
#     452         {
#     453             "text": generation.text,
#    (...)    460         }
#     461     )
#     462 else:
# --> 463     response = completion_with_retry(
#     464         self, prompt=_prompts, run_manager=run_manager, **params
#     465     )
#     466     if not isinstance(response, dict):
#     467         # V1 client returns the response in an PyDantic object instead of
#     468         # dict. For the transition period, we deep convert it to dict.
#     469         response = response.dict()
#
# File e:\MCA\Sem3\GenAI\Lab\.venv\Lib\site-packages\langchain_community\llms\openai.py:129, in completion_with_retry(llm, run_manager, **kwargs)
#     125 @retry_decorator
#     126 def _completion_with_retry(**kwargs: Any) -> Any:
#     127     return llm.client.create(**kwargs)
# --> 129 return _completion_with_retry(**kwargs)
#
# File e:\MCA\Sem3\GenAI\Lab\.venv\Lib\site-packages\tenacity\__init__.py:338, in BaseRetrying.wraps.<locals>.wrapped_f(*args, **kw)
#     336 copy = self.copy()
#     337 wrapped_f.statistics = copy.statistics  # type: ignore[attr-defined]
# --> 338 return copy(f, *args, **kw)
#
# File e:\MCA\Sem3\GenAI\Lab\.venv\Lib\site-packages\tenacity\__init__.py:477, in Retrying.__call__(self, fn, *args, **kwargs)
#     475 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     476 while True:
# --> 477     do = self.iter(retry_state=retry_state)
#     478     if isinstance(do, DoAttempt):
#     479         try:
#
# File e:\MCA\Sem3\GenAI\Lab\.venv\Lib\site-packages\tenacity\__init__.py:378, in BaseRetrying.iter(self, retry_state)
#     376 result = None
#     377 for action in self.iter_state.actions:
# --> 378     result = action(retry_state)
#     379 return result
#
# File e:\MCA\Sem3\GenAI\Lab\.venv\Lib\site-packages\tenacity\__init__.py:400, in BaseRetrying._post_retry_check_actions.<locals>.<lambda>(rs)
#     398 def _post_retry_check_actions(self, retry_state: "RetryCallState") -> None:
#     399     if not (self.iter_state.is_explicit_retry or self.iter_state.retry_run_result):
# --> 400         self._add_action_func(lambda rs: rs.outcome.result())
#     401         return
#     403     if self.after is not None:
#
# File C:\Python313\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File C:\Python313\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception is not None:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File e:\MCA\Sem3\GenAI\Lab\.venv\Lib\site-packages\tenacity\__init__.py:480, in Retrying.__call__(self, fn, *args, **kwargs)
#     478 if isinstance(do, DoAttempt):
#     479     try:
# --> 480         result = fn(*args, **kwargs)
#     481     except BaseException:  # noqa: B902
#     482         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File e:\MCA\Sem3\GenAI\Lab\.venv\Lib\site-packages\langchain_community\llms\openai.py:127, in completion_with_retry.<locals>._completion_with_retry(**kwargs)
#     125 @retry_decorator
#     126 def _completion_with_retry(**kwargs: Any) -> Any:
# --> 127     return llm.client.create(**kwargs)
#
# File e:\MCA\Sem3\GenAI\Lab\.venv\Lib\site-packages\openai\api_resources\completion.py:25, in Completion.create(cls, *args, **kwargs)
#      23 while True:
#      24     try:
# ---> 25         return super().create(*args, **kwargs)
#      26     except TryAgain as e:
#      27         if timeout is not None and time.time() > start + timeout:
#
# File e:\MCA\Sem3\GenAI\Lab\.venv\Lib\site-packages\openai\api_resources\abstract\engine_api_resource.py:153, in EngineAPIResource.create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     127 @classmethod
#     128 def create(
#     129     cls,
#    (...)    136     **params,
#     137 ):
#     138     (
#     139         deployment_id,
#     140         engine,
#    (...)    150         api_key, api_base, api_type, api_version, organization, **params
#     151     )
# --> 153     response, _, api_key = requestor.request(
#     154         "post",
#     155         url,
#     156         params=params,
#     157         headers=headers,
#     158         stream=stream,
#     159         request_id=request_id,
#     160         request_timeout=request_timeout,
#     161     )
#     163     if stream:
#     164         # must be an iterator
#     165         assert not isinstance(response, OpenAIResponse)
#
# File e:\MCA\Sem3\GenAI\Lab\.venv\Lib\site-packages\openai\api_requestor.py:298, in APIRequestor.request(self, method, url, params, headers, files, stream, request_id, request_timeout)
#     277 def request(
#     278     self,
#     279     method,
#    (...)    286     request_timeout: Optional[Union[float, Tuple[float, float]]] = None,
#     287 ) -> Tuple[Union[OpenAIResponse, Iterator[OpenAIResponse]], bool, str]:
#     288     result = self.request_raw(
#     289         method.lower(),
#     290         url,
#    (...)    296         request_timeout=request_timeout,
#     297     )
# --> 298     resp, got_stream = self._interpret_response(result, stream)
#     299     return resp, got_stream, self.api_key
#
# File e:\MCA\Sem3\GenAI\Lab\.venv\Lib\site-packages\openai\api_requestor.py:700, in APIRequestor._interpret_response(self, result, stream)
#     692     return (
#     693         self._interpret_response_line(
#     694             line, result.status_code, result.headers, stream=True
#     695         )
#     696         for line in parse_stream(result.iter_lines())
#     697     ), True
#     698 else:
#     699     return (
# --> 700         self._interpret_response_line(
#     701             result.content.decode("utf-8"),
#     702             result.status_code,
#     703             result.headers,
#     704             stream=False,
#     705         ),
#     706         False,
#     707     )
#
# File e:\MCA\Sem3\GenAI\Lab\.venv\Lib\site-packages\openai\api_requestor.py:765, in APIRequestor._interpret_response_line(self, rbody, rcode, rheaders, stream)
#     763 stream_error = stream and "error" in resp.data
#     764 if stream_error or not 200 <= rcode < 300:
# --> 765     raise self.handle_error_response(
#     766         rbody, rcode, resp.data, rheaders, stream_error=stream_error
#     767     )
#     768 return resp
#
# InvalidRequestError: Input required: specify "prompt"

# %% [markdown]
# ## Select which AI to use for your prompt
#
# Enter your prompt and choose which AI backend to use (Hugging Face, Gemini, or OpenRouter).

# %%
# User input for prompt and AI selection
prompt_text = input("Enter your prompt: ")
ai_choice = input("Choose AI (huggingface/gemini/openrouter): ").strip().lower()

if ai_choice == "huggingface":
    response = hf_llm(prompt_text)
    print("Hugging Face Response:", response)
elif ai_choice == "gemini":
    response = gemini_model.generate_content(prompt_text)
    print("Gemini Response:", response.text)
elif ai_choice == "openrouter":
    response = openrouter_llm(prompt_text)
    print("OpenRouter Response:", response)
else:
    print("Invalid choice. Please select huggingface, gemini, or openrouter.")
